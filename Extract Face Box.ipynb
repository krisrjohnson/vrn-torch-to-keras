# %%
# %load_ext autoreload
# %autoreload 2
import os, pathlib
from matplotlib import pyplot as plt
import cv2
import dlib
import numpy as np

# %%
# !pip install dlib

# %% [markdown]
# Given an input img of whatever shape, return coordinates of bounding box of face.
#
# input is img frame. Shape_predictor_68_face_landmarks.dat file only necessary for predicting landmarks!
#
# min_x, max_x, min_y, max_y

# %%
def extract_face(frame):
    '''returns list of face rects: [rectangle(min_x,min_y, max_x,max_y),...], 
    can be used frame[min_y:max_y, min_x:max_x] to return face bounding box (could use padding)'''
    detector = dlib.get_frontal_face_detector()
    gray = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
    return detector(gray) #detector(gray, 1)

# %%
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('data/shape_predictor_68_face_landmarks.dat')

# %%
frame = cv2.imread('dr_mark.jpg', cv2.IMREAD_GRAYSCALE)

# %%
frame.shape #width by height
# Out:
# (3264, 2448)

# %%
faces = detector(frame)

# %%
faces[0]
# Out:
# rectangle(753,1352,1523,2122)

# %%
plt.imshow(frame)

# %%
plt.imshow(frame[1352:2122, 753:1523])

# %%
cv2.startWindowThread()
cv2.namedWindow('frame')
cv2.imshow('frame', frame[753:1523, 1352:2122])

cv2.waitKey(0)
# Out:
# 13

# %%
cv2.destroyAllWindows()
